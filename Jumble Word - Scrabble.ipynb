# %% [markdown]
# The purpose of this notebook is to take a list of:
#
# 1. 9-letter words from the Official Scrabble Players Dictionary (OSPD)
# 2. Exclude Plurals
# 3. Exclude words that exceed the number of tiles in a Scrabble set
#
# And find the list of highest scoring words given these parameters.

# %%
import pandas as pd
import numpy as np

# %%
ospd = pd.read_csv('ospd.txt')
ospd = ospd[(ospd['Word'].str.len() == 9)].reset_index().drop('index',axis=1)

# %%
ospd.head()
# Out:
#         Word
# 0  aardvarks
# 1  aasvogels
# 2  abamperes
# 3  abandoned
# 4  abandoner

# %%
#Remove Plurals

import inflect
p = inflect.engine()
word_list = list(filter(lambda item: p.singular_noun(item) == False,ospd['Word']))

# %%
word_list[:5]
# Out:
# ['abandoned', 'abandoner', 'abasement', 'abashment', 'abatement']

# %% [markdown]
# # Scrabble Tile Values

# %%
tile_dict = {"a":{"value":1,"count":9},
             "b":{"value":3,"count":2},
             "c":{"value":2,"count":2},
             "d":{"value":2,"count":4},
             "e":{"value":1,"count":12},
             "f":{"value":4,"count":2},
             "g":{"value":2,"count":3},
             "h":{"value":4,"count":2},
             "i":{"value":1,"count":9},
             "j":{"value":8,"count":1},
             "k":{"value":5,"count":1},
             "l":{"value":1,"count":4},
             "m":{"value":3,"count":2},
             "n":{"value":1,"count":6},
             "o":{"value":1,"count":8},
             "p":{"value":3,"count":2},
             "q":{"value":10,"count":1},
             "r":{"value":1,"count":6},
             "s":{"value":1,"count":4},
             "t":{"value":1,"count":6},
             "u":{"value":1,"count":4},
             "v":{"value":4,"count":2},
             "w":{"value":4,"count":2},
             "x":{"value":8,"count":1},
             "y":{"value":4,"count":2},
             "z":{"value":10,"count":1}
            }

# %%
tile_dict["a"]["value"]
# Out:
# 1

# %%
tiledf = pd.DataFrame.from_dict(tile_dict, orient='index')
tiledf
# Out:
#    value  count
# a      1      9
# b      3      2
# c      2      2
# d      2      4
# e      1     12
# f      4      2
# g      2      3
# h      4      2
# i      1      9
# j      8      1
# k      5      1
# l      1      4
# m      3      2
# n      1      6
# o      1      8
# p      3      2
# q     10      1
# r      1      6
# s      1      4
# t      1      6
# u      1      4
# v      4      2
# w      4      2
# x      8      1
# y      4      2
# z     10      1

# %%
#Need a new version of word_list using the subindex version
value_list = [[sum(tile_dict[i]["value"] for i in word_list[r])]for r in range(len(word_list))]
value_list[:5]
# Out:
# [[13], [12], [13], [16], [13]]

# %%
#Determine if letter count exceeds possible letter count

letter_count = [[word_list[r].count(word_list[r][i]) <= tile_dict[word_list[r][i]]["count"] for i in range(len(word_list[0]))] for r in range(len(word_list))]

# %%
#Check for any instances where a letter is False, i.e. exceeds the letter count.
letter_check = [all(letter_count[i]) for i in range(len(word_list))]
letter_check[:10]

#all(letter_count[99])
# Out:
# [True, True, True, True, True, True, True, True, True, True]

# %%
d = {'Word':word_list,'Value':value_list,'Letter Check':letter_check}

# %%
df = pd.DataFrame(d)
df.head()
# Out:
#         Word Value  Letter Check
# 0  abandoned  [13]          True
# 1  abandoner  [12]          True
# 2  abasement  [13]          True
# 3  abashment  [16]          True
# 4  abatement  [13]          True

# %%
df[df['Word']=='showbizzy']
# Out:
#             Word Value  Letter Check
# 11550  showbizzy  [38]         False

# %%
df_valid = df[df['Letter Check']==True]

# %% [markdown]
# # Jumble Words with the Highest Score in Scrabble

# %%
df_valid.sort_values('Value',ascending=False)
# Out:
#             Word Value  Letter Check
# 4537   exoenzyme  [30]          True
# 7366   maximized  [30]          True
# 6696   jarovized  [29]          True
# 6845   krummholz  [29]          True
# 7367   maximizer  [29]          True
# 6702   jayhawker  [29]          True
# 10889  rhythmize  [29]          True
# 4486   exchequer  [29]          True
# 6795   kibbutzim  [28]          True
# 4326   equalized  [28]          True
# 6052   hydrolyze  [28]          True
# 6691   japanized  [28]          True
# 12115  squeezing  [28]          True
# 4322   epoxidize  [28]          True
# 7082   liquidize  [28]          True
# 9988   quantized  [28]          True
# 8788   oxidizing  [27]          True
# 7959   mythicize  [27]          True
# 11166  schmaltzy  [27]          True
# 9989   quantizer  [27]          True
# 2037   cheapjack  [27]          True
# 10001  queaziest  [27]          True
# 9967   pyrolyzed  [27]          True
# 3336   deoxidize  [27]          True
# 6039   hybridize  [27]          True
# 6097   hypoxemic  [27]          True
# 6703   jaywalked  [27]          True
# 6793   kibbitzed  [27]          True
# 5815   hemolyzed  [27]          True
# 9997   quartzite  [27]          True
# ...          ...   ...           ...
# 471    annotator   [9]          True
# 10749  restitute   [9]          True
# 11070  sanitaria   [9]          True
# 476    annuitant   [9]          True
# 12207  steeliest   [9]          True
# 804    attrition   [9]          True
# 10935  roisterer   [9]          True
# 798    attenuate   [9]          True
# 8275   nurturant   [9]          True
# 490    antenatal   [9]          True
# 491    antennule   [9]          True
# 11091  sartorial   [9]          True
# 10754  restraint   [9]          True
# 12882  tensioner   [9]          True
# 7137   loneliest   [9]          True
# 11106  saturnine   [9]          True
# 13190  translate   [9]          True
# 823    austenite   [9]          True
# 13188  transient   [9]          True
# 7967   nanotesla   [9]          True
# 11104  saturator   [9]          True
# 12880  tensional   [9]          True
# 11094  satellite   [9]          True
# 10759  resultant   [9]          True
# 817    auntliest   [9]          True
# 6412   innersole   [9]          True
# 11096  satiation   [9]          True
# 12224  sterilant   [9]          True
# 13058  titration   [9]          True
# 10806  retreater   [9]          True
#
# [14313 rows x 3 columns]
